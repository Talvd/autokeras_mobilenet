# %%
# import the necessary packages
from sklearn.metrics import classification_report
from keras.datasets import cifar10
import autokeras as ak
import os
import datetime
import torch
from autokeras.utils import pickle_from_file
from keras.models import load_model
from thop import profile    #pip install --upgrade git+https://github.com/Lyken17/pytorch-OpCounter.git
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
print(ak.constant.Constant.BACKEND)
# Out:
# torch

# %%
def runMain():
    # load the training and testing data, then scale it into the
    # range [0, 1]
    print(datetime.datetime.now())
    print("[INFO] loading CIFAR-10 data...")
    ((trainX, trainY), (testX, testY)) = cifar10.load_data()
    trainX = trainX.astype("float") / 255.0
    testX = testX.astype("float") / 255.0

    # initialize the label names for the CIFAR-10 dataset
    labelNames = ["airplane", "automobile", "bird", "cat", "deer",
        "dog", "frog", "horse", "ship", "truck"]

    # initialize the output directory
    OUTPUT_PATH = "output"

    seconds= 12*60*60 #12 hour
    print(datetime.datetime.now())
    print("[INFO] training model for {} seconds max...".format(seconds))
    model = ak.ImageClassifier(path=os.path.join(os.getcwd(),"automodels"),verbose=True, 
                               augment=True) #, searcher_args={'trainer_args':{'max_iter_num':10}})
    model.fit(trainX, trainY, time_limit=seconds)
    print(datetime.datetime.now())
    #saveModel(model)
    # print("[INFO] final_fit")
    # model.final_fit(trainX, trainY, testX, testY, retrain=True)

    # evaluate the Auto-Keras model
    # score = model.evaluate(testX, testY)
    # predictions = model.predict(testX)
    # report = classification_report(testY, predictions,target_names=labelNames)

# write the report to disk
# p = os.path.join(OUTPUT_PATH, "{}.txt".format(seconds))
# f = open(p, "w")
# f.write(report)
# f.write("\nscore: {}".format(score))
# f.close()

# %%
def get_flops(model):
    return profile(model, input_size=(1, 3, 32,32))

# %%
def getModule():
    path = os.path.join('automodels', 'module')
    cnn_module = pickle_from_file(path)
    return cnn_module

# %%
def saveModel(model):
    # serialize model to JSON
    model_json = model.to_json()
    with open("model.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("model.h5")
    print("Saved model to disk")

# %%
def getModelData(module):
    with open("results.txt", "a") as resfile:
        resfile.write("model Id,total params,file size,flops,params from profile,metric,graph size\n")
    for item in module.searcher.history:  
        model_id = item['model_id']
        graph = module.searcher.load_model_by_id(model_id)
        model = graph.produce_model()
        print(model)
        flops, params = get_flops(model)
        file_path=os.path.join('automodels', "{}.pt".format(model_id))
        torch.save(model.state_dict(), file_path)
        pytorch_total_params = sum(p.numel() for p in model.parameters())
        file_size = os.path.getsize(file_path)
        print("\nmodel Id {}:\n   total params = {}\n   file size = {} kB\n   flops: {}\n   params from profile: {}".format(model_id,pytorch_total_params, file_size/1000, flops, params))
        with open("results.txt", "a") as resfile:
            resfile.write("{},{},{},{},{},{},{}\n".format(model_id,pytorch_total_params, file_size/1000, flops, params,item['metric_value'],graph.size()))

# %%
if __name__ == "__main__":
    runMain()
# Out:
# 2019-07-18 19:00:26.109902
# [INFO] loading CIFAR-10 data...
# 2019-07-18 19:00:27.993851
# [INFO] training model for 43200 seconds max...
# Saving Directory: /home/Tal/AutoDLProject/AutoDLProject/automodels
# Preprocessing the images.
# Preprocessing finished.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           0            |   4.467973697185516    |         0.6088         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           1            |   4.941076922416687    |   0.5524000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           2            |   3.9422569155693052   |         0.6568         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           3            |   4.130715191364288    |          0.63          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           4            |   4.142331790924072    |         0.632          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           5            |   4.037776625156402    |         0.6524         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           6            |   3.8859679102897644   |         0.6548         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           7            |   3.470645177364349    |         0.6968         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           8            |   3.6032232880592345   |         0.6792         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           9            |   3.0255764603614805   |         0.736          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           10           |   3.1525076389312745   |         0.7196         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           11           |   3.069947385787964    |         0.7292         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           12           |   2.9871159553527833   |         0.7308         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           13           |   2.9617504596710207   |         0.738          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           14           |   3.124434173107147    |   0.7295999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           15           |   2.957986032962799    |   0.7367999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           16           |   2.814296770095825    |         0.7476         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           17           |   2.8964853048324586   |         0.7452         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           18           |   2.8359978675842283   |   0.7475999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           19           |    2.77771475315094    |   0.7495999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           20           |   2.679112100601196    |   0.7699999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           21           |   2.720368945598602    |   0.7699999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 22               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           22           |   2.632406842708588    |         0.7728         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 23               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           23           |   2.721760320663452    |   0.7567999999999999   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 24               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           24           |   2.6118838667869566   |         0.7684         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 25               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           25           |   2.6165730476379396   |         0.7788         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 26               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           26           |   2.580268132686615    |         0.7776         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 27               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           27           |   2.654110014438629    |         0.7664         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 28               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           28           |   2.681076866388321    |         0.772          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 29               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           29           |   2.612639492750168    |         0.7804         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 30               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           30           |   2.6388637900352476   |         0.7748         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 31               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           31           |   2.638699507713318    |         0.776          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 32               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           32           |   2.577770411968231    |         0.7832         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 33               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           33           |   2.6419036388397217   |         0.7804         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 34               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           34           |   2.604772388935089    |         0.782          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 35               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           35           |   2.5868717193603517   |   0.7916000000000001   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 36               |
# +----------------------------------------------+
# Epoch-11, Current Metric - 0.758:   8%|█▊                      | 30/387 [00:06<01:00,  5.91 batch/s]

# %%
getModelData(getModule())
